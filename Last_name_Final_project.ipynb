# %% [markdown]
# <a href="https://colab.research.google.com/github/carighi/al_ml_workshop/blob/main/Last_name_Final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Final Machine Learning Project
#
# In this project you will go over the following steps for classifying flowers, based on sepal and petal information
# ![Screenshot 2024-05-10 at 13-32-04 IRIS Flowers Classification Using Machine Learning.png](data:image/png;base64,...)
#
# Caption: The image shows the three Iris species related to the dataset. The Sepal and Petal are shown in each flower for your reference.
# *Source:Analytics Vidhya*

# %% [markdown]
# The iris dataset is a small classic dataset. It is widely used as a classification task example. The dataset has been modified to provide a different scenario for your final project.
#
# Here are the different steps
#
# 1-Define a problem
#
# 2-Prepare the data
#
# 3-Evaluate algorithms
#
# 4-Present results
#
#
# Save a copy of the notebook replacing Last_name with your last name. Follow instructions and answer questions. At the end, download the notebook as ipynb extension to upload in the assignment page.
#
# Here is a link to [useful tips](https://colab.research.google.com/github/carighi/al_ml_workshop/blob/main/Useful_tips.ipynb)

# %% [markdown]
# You will need a number of libraries. In the cell below most of the ones you may need are there. Remember to import as needed

# %%
from pandas import read_csv
from numpy import asarray
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# #1 Load dataset
#
# Use pandas to load the data. The dataset is in csv format.
# Data can be uploaded from
# URL https://raw.githubusercontent.com/carighi/al_ml_workshop/main/data/BINF601final_project_dataset.csv
#
# Take a moment to read the [Readme file](https://raw.githubusercontent.com/carighi/al_ml_workshop/main/data/Readme_final_project_dataset.txt) to learn about this dataset.
#
# **Question 1-**What is this dataset about?
#
# **Question 2-**What is the problem at hand?

# %% [markdown]
# #2 Summarize the dataset
# 1. Check on the dimension of the dataset
# 2. Display some of the data (a few rows)
# 3. Statistical summary of all attributes
# 4. List data types
# 5. Get breakdown of the data by class variable (hint: .groupby)

# %%
#<your code here>

# %% [markdown]
# **Question 3-**Which ones are the predictive variables?
#
#
# **Question 4-**Which one is the target (what we want to predict)?
# What type of variable is the target (categorical, numerical)?
#
# **Question 5-**How many observations are there for each class?

# %% [markdown]
# #3- Preparing data
#
# *   Check for duplicate rows and remove
# *   Check for missing values (NaN and 0), at least 0 does not make sense for length and width measurements. Remove rows only if affecting a small number of observations (<5 rows), otherwise impute these values
# *   Store the data under a dataframe called dataset_ready
# *   Provide shape, distribution by class and summary statistics of the final dataset (dataset_ready)
#
#
#
# **Question 6-** Comment on the outcome of these data preparation steps.

# %%
#Your code here. Remember to assign your final dataset to dataset_ready

# %% [markdown]
# #4-Data visualization
# ###Understand each attribute by looking into Univariate plots
# Create a histogram for each individual variable in dataset_ready

# %% [markdown]
# **Question 7-** Which variables seem to follow Gaussian distrubution?

# %% [markdown]
# ### Visualization of interactions between variables
# Multivariate plots. Since we have not plotted these before, follow the code below to plot these.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dataset_ready)
plt.show

# %% [markdown]
# **Question 8-** What pair of attributes seem to be correlated? (hint: those with diagonal grouping)

# %% [markdown]
# # 5 Evaluate some algorithms
#
# Create models of the data and estimate accuracy on unseen data (test set)
#
# Steps:
#
# 1- Separate data into variables and target
#
# 2- Separate dataset into training and test sets
#
# 3- Build models to predict species from the flower measurements:
# Use K-NN and SVM
#
# 4-Evaluate the performance and select the best model
#
# Follow the indications below

# %% [markdown]
# ###Separate validation dataset
# Split dataset into 2 sets: 80% training (use _train), and 20 % testing set (use _validation). Testing set will be hold back

# %%
#your code here

# %% [markdown]
# **Question 9** - What is the size of your train and test datasets?

# %% [markdown]
# ##Classification with SVM
#
# Run SVM algorithm. Try linear SVM and 2 different C values (0.1, and 10). Do not forget to add random_state parameter so your results are reproducible.
#
# **Question 10** -  Which value for C gave the best mean accuracy?
#
# If you got different accuracy, check the confusion matrix for both and indicate where the differences are (e.g., the one with less accuracy may have more false positives)
#
# In the end print the classification report (classification_report)

# %%
#your code here

# %% [markdown]
# **Question 11-** Which C value gave the best mean accuracy?

# %% [markdown]
# ##Classification with k-nearest neighbor method
# Now apply the KneighborsClassifier with two different k (n_neighbors=3 and 6)
# Similar to previous, compare mean accuracy, print the confusion matrices and print the classification report.
#
# **Question 12-** Which k value gave the best mean accuracy?

# %%
#your code here

# %% [markdown]
# **Question 13** - The target class in the dataset is categorical, What did scikitlearn do automatically that otherwise needed to be done before applying ML?
#
# Finally, Summarize your results in terms of what method performed better based on your evaluation.
