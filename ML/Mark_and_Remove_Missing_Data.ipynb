# %% [markdown]
# <a href="https://colab.research.google.com/github/carighi/al_ml_workshop/blob/main/ML/Mark_and_Remove_Missing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Mark and Remove Missing Data**

# %% [markdown]
# In this tutorial, you will learn:
#
# * Analyze clinical datasets to distinguish between true zero values and improperly coded missing data using domain knowledge.
# * Evaluate the sensitivity of different machine learning algorithms (e.g., LDA vs. Tree-based models) to missing values.
# * Critique the statistical and clinical consequences of listwise deletion (dropna()) on dataset representativeness and model bias.
#
# Adapted from Jason Brownlee. 2020. [Data Preparation for Machine Learning](https://machinelearningmastery.com/data-preparation-for-machine-learning/).

# %% [markdown]
# #Diabetes Dataset
# The dataset classifies patient data as
# either an onset of diabetes within five years or not. There are 768 examples and eight input variables. It is a binary classification problem.
#
# You can learn more about the dataset here:
#
# * Diabetes Dataset File ([pima-indians-diabetes.csv](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv))
# * Diabetes Dataset Details ([pima-indians-diabetes.names](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.names))
#
# The description of Diabetes Dataset can be found [here](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database).

# %% [markdown]
# ##Download Diabetes data files

# %%
# Now that you know how to use !wget to download files from internet, do so for both the diabetes dataset file (name it pima-indians-diabetes.csv) and the diabetes dataset metadata (name it pima-indians-diabetes.names)
# Display the first rows for the csv file.

# %%
# @title Check answer here
# !wget "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.csv" -O pima-indians-diabetes.csv
# !wget "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.names" -O pima-indians-diabetes.names
# !head pima-indians-diabetes.csv

# %%
# load the dataset and check the datatypes
import pandas as pd
# read the dataset and store it in variable dataset.
dataset = pd.read_csv('pima-indians-diabetes.csv', header=None)
# let's include the column headers (from metadata)
dataset.columns = ['Number of times pregnant', 'Plasma glucose concentration', 'Diastolic blood pressure', 'Triceps skinfold thickness', '2-Hour serum insulin', 'Body mass index', 'Diabetes pedigree function', 'Age', 'Class variable (0 or 1)']
# Check the data types in the different columns (Hint: .dtypes)
#Your code here

# %%
# @title Check answer here
# load the dataset and check the datatypes
import pandas as pd
# read the dataset and store it in variable dataset.
dataset = pd.read_csv('pima-indians-diabetes.csv', header=None)
# let's include the column headers (from metadata)
dataset.columns = ['Number of times pregnant', 'Plasma glucose concentration', 'Diastolic blood pressure', 'Triceps skinfold thickness', '2-Hour serum insulin', 'Body mass index', 'Diabetes pedigree function', 'Age', 'Class variable (0 or 1)']
# Check the data types in the different columns (Hint: .dtypes)
dataset.dtypes

# %% [markdown]
# ### Computational vs. Statistical Data Types
#
#   Let's take a moment to think of the data types here. All attributes, including the class variable, are loaded as numerical data types (specifically, 64-bit integers or floats). This is a computational data type. This is how the computer stores the data in memory (e.g., int64, float64). Because the CSV file only contains numbers, Pandas correctly infers that everything is a number.
#   However, it is critical to know the actual meaning of the data or its statistical data type. In this dataset, in particular:
#    * Continuous Numerical: e.g., BMI, Plasma Glucose, Diastolic Blood Pressure.
# *   Discrete Numerical: e.g., Number of times pregnant.
# *   Nominal Categorical: The Class Variable 0 (tested negative for diabetes) or 1 (tested positive for
#    diabetes).
#
#    Note that the class variable has been encoded to be represented as numbers instead of strings as numbers is what machines understand. We will learn more about this later on.

# %%
# summarize the dataset (Hint: .describe())
#Your code here

# %%
# @title Check answer here
# summarize the dataset (Hint: .describe())
dataset.describe()

# %% [markdown]
# We can see that there are columns that have a minimum value of zero (0).
# On some columns, a value of zero does not make sense and indicates an invalid or missing value.

# %% [markdown]
# Specifically, the following columns have an invalid zero minimum value:
# 1. Plasma glucose concentration
# 1. Diastolic blood pressure
# 1. Triceps skinfold thickness
# 1. 2-Hour serum insulin
# 1. Body mass index
#
# We can confirm this by looking at the raw data and printing out the first 20 rows of data.

# %%
# summarize the first 20 rows of data
# your code here

# %% [markdown]
# We can get a count of the number of missing values on each of these columns using the .sum() function
# Formatl <dataframe>.sum()
# More info on this function in [pandas website](https://https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sum.html#pandas.DataFrame.sum)

# %%
# Summarizing the number of missing values for each variable
# count the number of missing values for each column indicated
num_missing = (dataset[['Plasma glucose concentration', 'Diastolic blood pressure', 'Triceps skinfold thickness', '2-Hour serum insulin', 'Body mass index']] == 0).sum()
# report the results
print(num_missing)

# %% [markdown]
# We can see that columns in dataset indexed 1, 2 and 5 have just a few zero values, whereas columns 3 and 4
# show a lot more, nearly half of the rows. This highlights that different missing value strategies
# may be needed for different columns, e.g., to ensure that there are still a sufficient number of
# records left to train a predictive model and that there is no bias introduced by removing them.

# %% [markdown]
# In Python, specifically Pandas, NumPy and Scikit-Learn, we mark missing values as NaN.
# Values with a NaN value are ignored from operations like sum, count, etc. We can mark values
# as NaN easily with the Pandas DataFrame by using the replace() function on a subset of
# the columns we are interested in. After we have marked the missing values, we can use the
# isnull() function to mark all of the NaN values in the dataset as True and get a count of the
# missing values for each column.

# %%
# Marking missing values with nan values
from numpy import nan
from pandas import read_csv
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan' in columns where 0 means missing, columns indexed (1-5). We do this applying the function to a subset.
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# count the number of nan values in each column. Hint: use .isnull().sum()
# your code here

# %%
# @title Check answer here
# Marking missing values with nan values
from numpy import nan
from pandas import read_csv
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan' in columns where 0 means missing, columns indexed (1-5). We do this applying the function to a subset.
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# count the number of nan values in each column. Hint: use .isnull().sum()
print (dataset.isnull().sum())

# %% [markdown]
# We can confirm by printing out the first 20 rows of data.

# %%
# Review data with missing values marked with a nan
from numpy import nan
from pandas import read_csv
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# view the first 20 rows of data
# your code here

# %%
# @title Check answer here
# Review data with missing values marked with a nan
from numpy import nan
from pandas import read_csv
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# view the first 20 rows of data
dataset.head(20)

# %% [markdown]
# #Missing Values Cause Problems
# Having missing values in a dataset can cause errors with some machine learning algorithms. We are going to try classification of diabetes vs non diabetes using Linear Discrimant Analysis or LDA. LDA is a technique used for classification tasks. LDA is a classification algorithm that finds a linear combination of features that characterizes or separates two or more classes of objects or events. It assumes that the input variables have a Gaussian distribution and the same variance. This algorithm is sensitive to missing data.
# When you run the next cell, you will get an error because of this.

# %%
# example where missing values cause errors
from numpy import nan
from pandas import read_csv
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan' in the subset of columns with index 1-5.
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# split dataset into inputs and outputs
values = dataset.values
X = values[:,0:8]
y = values[:,8]
# define the model
model = LinearDiscriminantAnalysis()
# define the model evaluation procedure using K fold cross-valiation
cv = KFold(n_splits=3, shuffle=True, random_state=1)
# evaluate the model accuracy score
result = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
# report the mean performance
print('Accuracy: %.3f' % result.mean())

# %% [markdown]
#  Here is a brief explanation of what each part the code does:
#
#     It imports necessary libraries and functions.
#     It reads the dataset from a CSV file using pandas' read_csv function.
#     It replaces all 0 values in columns 1 to 5 with NaN (Not a Number), as these might represent missing data.
#     It removes all rows with any missing values using the dropna function.
#     It separates the dataset into input features (X) and the target variable (y).
#     It creates an LDA model.
#     It sets up a K-Fold cross-validation with 3 splits.
#     It evaluates the model using cross-validation and calculates the mean accuracy.
#     Finally, it prints the mean accuracy of the model.

# %% [markdown]
# #Remove Rows With Missing Values (with caution!)
#
# We need to address the missing values to be able to rerun LDA. The simplest approach for dealing with missing values is to remove entire predictor(s)
# and/or sample(s) that contain missing values.
#
# However, be aware that although it is operationally simple to remove the observations with missing values, it may not be ther right thing to do in the context of your analysis.
#
# For example for the columns, 2h-serum insulin and Skinfold thickness, "nearly a third to half of the rows" are missing. Using dropna() will discard ~30-50% of the patient cohort. This comes with some consequences. For example in clinical trials or observational studies, data is rarely "Missing Completely At Random" (MCAR). Perhaps the patients missing insulin tests were those without good health insurance, or those treated at a rural clinic. By dropping them, the model becomes biased toward affluent/urban patients.
#
# Thus, we are doing this data removal as an example to show that some ML models do not work with missing data. Later on, we will learn of methods for imputation.
#
#
# To remove observations we will use the pandas dropna() function.

# %%
# example of removing rows that contain missing values
from numpy import nan
from pandas import read_csv
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# summarize the shape of the raw data
print(dataset.shape)
# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# drop rows with missing values and store it in variable dataset_d.
# Your code here
dataset_d=dataset.dropna()
dataset_d.head(10)
# summarize the shape of the data with missing rows removed
dataset_d.shape

# %% [markdown]
# We now have a dataset that we could use to evaluate an algorithm sensitive to missing values
# like LDA. Let's try again!

# %%
# evaluate model on data after rows with missing data are removed
from numpy import nan
from pandas import read_csv
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
# load the dataset
dataset = read_csv('pima-indians-diabetes.csv', header=None)
# replace '0' values with 'nan'
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
# drop rows with missing values
dataset_d= dataset.dropna()
# split dataset into inputs and outputs
values = dataset_d.values
# In this case, values is a 2D array. The : character means "all rows" and 0:8 means "columns from 0 to 7". So, X = values[:,0:8] is selecting all rows and the first 8 columns of the data to be assigned to X. This is typically done when you want to separate your features (input for your model) from your target variable.
X = values[:,0:8]
# What values are then assigned to y? What is y?
y = values[:,8]
# define the model
model = LinearDiscriminantAnalysis()

# define the model evaluation procedure. Cross-validation is a resampling procedure used to evaluate machine learning models on a limited data sample.
# The KFold divides all the samples into 'k' groups of samples, called folds. Here, it's dividing the data into 3 folds.
cv = KFold(n_splits=3, shuffle=True, random_state=1)

# evaluate the model accuracy score. It is fitting the LDA model on the training portion of the fold, making predictions on the test portion of the fold, and then calculating the accuracy of those predictions
result = cross_val_score(model, X, y, cv=cv, scoring='accuracy')

# report the mean performance. This line is printing the mean accuracy of the model across all folds of the cross-validation.
# The %.3f is a placeholder for a floating-point number, with 3 digits after the decimal point.
# The % operator is then used to insert the mean accuracy (result.mean()) into this placeholder
print('Accuracy: %.3f' % result.mean())

# %% [markdown]
# ##Cost of Deletion
# We are going to check now the class distribution (non-diabetic vs diabetic) before and after removing the observations to find out the consequences.

# %%
# 1. Class Distribution BEFORE dropna() ---
print("BEFORE dropna():")
total_before = len(dataset)
print(f"Total Patients: {total_before}")
#counting per class (column indexed 8 is the class column)
print(dataset[8].value_counts())
#same in percentage
print("\nPercentage Breakdown:")
print(dataset[8].value_counts(normalize=True) * 100)
#adding a separator
print("-" * 40)

# --- 2. Apply dropna() to a new dataframe ---
# We use a new variable so we don't destroy the original dataset yet
dataset_dropped = dataset.dropna()

# --- 3. Class Distribution AFTER dropna() ---
print("\nAFTER dropna():")
total_after = len(dataset_dropped)
print(f"Total Patients: {total_after}")
print(dataset_dropped[8].value_counts())
print("\nPercentage Breakdown:")
print(dataset_dropped[8].value_counts(normalize=True) * 100)
#adding a separator
print("-" * 40)

# Calculate how many patients were lost
patients_lost = total_before - total_after
print(f"\nTotal Patients Lost: {patients_lost} ({(patients_lost/total_before)*100:.1f}%)")

# %% [markdown]
# ## Reflection Questions:
#
# What percentage of the total patient cohort was deleted when you used dropna()?
#
# Did the ratio of Diabetic (1) to Non-Diabetic (0) patients change?
#
# Clinical Implication: If the missing values belonged predominantly to patients with severe diabetes who were too sick to complete all their lab tests, how might removing them completely bias the machine learning model?
