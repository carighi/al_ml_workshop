# %% [markdown]
# <a href="https://colab.research.google.com/github/carighi/al_ml_workshop/blob/main/Additional_exercises/Exercises_additional_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Imageio](https://imageio.readthedocs.io/en/stable/) is a library package for image analysis. We will use it here to upload a medical image and do some operations. We will also upload matplotlib for visualization.

# %%
#exercise 1a
#getting the needed libraries
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt

#lets read an image file
image = iio.imread("https://raw.githubusercontent.com/carighi/al_ml_workshop/main/Additional_exercises/MRIgliomapositiveimages/image(2).jpg")

#let's see what type of object it is, using type function
type(image)
# Out:
# numpy.ndarray

# %%
#let's display the array
image
# Out:
# array([[[12, 12, 12],
#         [11, 11, 11],
#         [10, 10, 10],
#         ...,
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9]],
#
#        [[12, 12, 12],
#         [11, 11, 11],
#         [10, 10, 10],
#         ...,
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9]],
#
#        [[12, 12, 12],
#         [11, 11, 11],
#         [10, 10, 10],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        ...,
#
#        [[11, 11, 11],
#         [11, 11, 11],
#         [10, 10, 10],
#         ...,
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9]],
#
#        [[11, 11, 11],
#         [11, 11, 11],
#         [10, 10, 10],
#         ...,
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9]],
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9]]], dtype=uint8)

# %%
#exercise 1b
#now let's find out the dimension of the array

image.shape
# Out:
# (641, 557, 3)

# %%
#exercise 1c
#let's display the image
plt.imshow(image)

# %%
#exercise 1c
#let's display the image
plt.imshow(image)
plt.axis('off')
plt.show()
